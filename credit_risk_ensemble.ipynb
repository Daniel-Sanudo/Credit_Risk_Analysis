# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Create results dictionary to store the results from each 
results_dict = {}

# Create method to fill the dictionary data
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

def model_results(model_name,y_test,y_pred):
    results_dict[model_name] = {
    'balanced_accuracy_score': balanced_accuracy_score(y_test, y_pred),
    'confusion_matrix' : confusion_matrix(y_test, y_pred),
    'classification_report_imbalanced' : pd.DataFrame(classification_report_imbalanced(y_test, y_pred, output_dict=True)).transpose().loc[['high_risk','low_risk']]
    }

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# https://help.lendingclub.com/hc/en-us/articles/215488038-What-do-the-different-Note-statuses-mean-

columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

# %%
# Load the data
file_path = 'https://raw.githubusercontent.com/Daniel-Sanudo/Credit_Risk_Analysis/main/LoanStats_2019Q1.csv'
df = pd.read_csv(file_path, skiprows=1)[:-2]
df = df.loc[:, columns].copy()

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# Remove the `Issued` loan status
issued_mask = df['loan_status'] != 'Issued'
df = df.loc[issued_mask]

# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100


# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
df = df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# ...

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Build a dataframe with all the dtypes and its respective column name
df_dtypes = pd.DataFrame({
    'column_name': df.columns,
    'dtype': df.dtypes
})
# Change index to a numerical value
df_dtypes.index = pd.Series(range(len(df.dtypes)))
# Find rows with a non-numerical data type
print(df_dtypes.groupby('dtype').count())
non_numerical_dtypes = df_dtypes.loc[(df_dtypes['dtype']=='object')&(df_dtypes['column_name']!='loan_status')]['column_name'].reset_index(drop=True)
non_numerical_dtypes
# Out:
#          column_name
# dtype
# float64           76
# object            10
# 0          home_ownership
# 1     verification_status
# 2                 issue_d
# 3              pymnt_plan
# 4     initial_list_status
# 5            next_pymnt_d
# 6        application_type
# 7           hardship_flag
# 8    debt_settlement_flag
# Name: column_name, dtype: object

# %%
# Create our features
X = df.copy().drop('loan_status',axis=1)
X = pd.get_dummies(X,columns=non_numerical_dtypes)

# Create our target
y = df['loan_status']

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# ...

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=18)

# %% [markdown]
# # Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble AdaBoost classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Print the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier onely, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

# Creating a StandardScaler instance.
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
    
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create a balanced random forest classifier.
brfc_model = BalancedRandomForestClassifier(n_estimators=128, random_state = 18)

# Fitting the model
brfc_model.fit(X_train_scaled, y_train)

# Making predictions using the testing data.
predictions = brfc_model.predict(X_test_scaled)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, predictions)
# Out:
# 0.7957716773246495

# %%
# Display the confusion matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[   65,    32],
#        [ 1344, 15764]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.05      0.67      0.92      0.09      0.79      0.60        97
#    low_risk       1.00      0.92      0.67      0.96      0.79      0.63     17108
#
# avg / total       0.99      0.92      0.67      0.95      0.79      0.63     17205

# %%
# Plot the features sorted in descending order by feature importance
features = sorted(zip(brfc_model.feature_importances_, X.columns), reverse=True)

features
# Out:
# [(0.07293779364180006, 'total_pymnt'),
#  (0.06346971393385599, 'total_rec_prncp'),
#  (0.06178571820420547, 'total_pymnt_inv'),
#  (0.05953218856366669, 'total_rec_int'),
#  (0.05307920023841388, 'last_pymnt_amnt'),
#  (0.025433466801114715, 'int_rate'),
#  (0.02168569321773021, 'issue_d_Jan-2019'),
#  (0.01983907408316343, 'installment'),
#  (0.01863132038693516, 'mo_sin_old_rev_tl_op'),
#  (0.018412971192226235, 'dti'),
#  (0.017359617910711857, 'issue_d_Mar-2019'),
#  (0.01663201396457809, 'max_bal_bc'),
#  (0.01602566543211182, 'out_prncp_inv'),
#  (0.015945231689856853, 'out_prncp'),
#  (0.015209244375771506, 'mo_sin_old_il_acct'),
#  (0.015055173322366581, 'total_bc_limit'),
#  (0.014678628398238228, 'bc_open_to_buy'),
#  (0.014460408478747652, 'annual_inc'),
#  (0.014254638632417917, 'avg_cur_bal'),
#  (0.014071849888335848, 'revol_bal'),
#  (0.01398762453160222, 'mths_since_rcnt_il'),
#  (0.013679276003879878, 'total_bal_il'),
# ...

# %%
# Plot the features

x = [f[1] for f in features][0:13]
y = [f[0] for f in features][0:13]

fig, ax = plt.subplots()
width = 0.5
ind = np.arange(len(y))  
ax.barh(ind, y, color="blue")
ax.set_yticklabels(x, minor=False)
plt.title('Feature Importances')
ax.set_yticks(ind+(width/6))
plt.xlabel('Feature')
plt.ylabel('Importance')  
bars = ax.barh(ind, y)
ax.bar_label(bars)
fig.set_size_inches(15,15)
plt.show()

# %%
model_results("BalancedRandomForestClassifier",y_test,predictions)
results_dict["BalancedRandomForestClassifier"]['classification_report_imbalanced']
# Out:
#                 pre       rec       spe        f1       geo       iba      sup
# high_risk  0.046132  0.670103  0.921440  0.086321  0.785786  0.601941     97.0
# low_risk   0.997974  0.921440  0.670103  0.958181  0.785786  0.632979  17108.0

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec_model = EasyEnsembleClassifier(n_estimators=128, random_state = 18)
eec_model.fit(X_train_scaled, y_train)
predictions = eec_model.predict(X_test_scaled)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, predictions)
# Out:
# 0.9179891724857726

# %%
# Display the confusion matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[   86,    11],
#        [  866, 16242]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.09      0.89      0.95      0.16      0.92      0.84        97
#    low_risk       1.00      0.95      0.89      0.97      0.92      0.85     17108
#
# avg / total       0.99      0.95      0.89      0.97      0.92      0.85     17205

# %%
model_results("EasyEnsembleClassifier",y_test,predictions)
results_dict["EasyEnsembleClassifier"]['classification_report_imbalanced']
# Out:
#                 pre       rec       spe        f1       geo       iba      sup
# high_risk  0.090336  0.886598  0.949380  0.163966  0.917452  0.836434     97.0
# low_risk   0.999323  0.949380  0.886598  0.973712  0.917452  0.847003  17108.0

# %%
# Results comparison
for model in results_dict.keys():
    print(f"Model: {model}")
    for key, value in results_dict[model].items():
        print(f"\n{key}\n{value}")
    print('------------------------------------------------------------------------------------------------')
# Out:
# Model: BalancedRandomForestClassifier
#
# balanced_accuracy_score
# 0.7957716773246495
#
# confusion_matrix
# [[   65    32]
#  [ 1344 15764]]
#
# classification_report_imbalanced
#                 pre       rec       spe        f1       geo       iba      sup
# high_risk  0.046132  0.670103  0.921440  0.086321  0.785786  0.601941     97.0
# low_risk   0.997974  0.921440  0.670103  0.958181  0.785786  0.632979  17108.0
# ------------------------------------------------------------------------------------------------
# Model: EasyEnsembleClassifier
#
# balanced_accuracy_score
# 0.9179891724857726
#
# confusion_matrix
# [[   86    11]
#  [  866 16242]]
#
# classification_report_imbalanced
#                 pre       rec       spe        f1       geo       iba      sup
# high_risk  0.090336  0.886598  0.949380  0.163966  0.917452  0.836434     97.0
# low_risk   0.999323  0.949380  0.886598  0.973712  0.917452  0.847003  17108.0
# ...
